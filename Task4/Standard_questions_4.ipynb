# %%
def cube(a):
    return a*a*a

measurements = [2.3, 3.5, 5.6, 12.8, 10.3, 7.2, 5.0, -1.2, 2.1]
cubed = map(cube, measurements)
print("Type of result is:", type(cubed))
print("cubed=", list(cubed))
# Out:
# Type of result is: <class 'map'>
# cubed= [12.166999999999996, 42.875, 175.61599999999996, 2097.1520000000005, 1092.7270000000003, 373.24800000000005, 125.0, -1.728, 9.261000000000001]

# %%
import numpy as np
a = np.random.randint(0, 6+1, 120)
print(a)

np.where(a == 6)
# Out:
# [2 6 4 5 0 1 6 6 1 5 5 1 5 6 4 1 0 4 6 1 6 4 3 6 3 6 0 3 4 4 5 5 3 5 3 1 4
#  6 2 6 4 6 0 0 3 2 2 3 2 0 4 1 3 4 0 4 2 2 6 4 3 3 6 3 3 5 0 2 6 4 0 1 5 3
#  6 3 5 5 4 4 2 1 0 2 5 0 0 3 2 2 3 5 6 1 5 5 2 6 3 5 3 3 5 3 1 5 4 1 4 4 2
#  5 3 1 0 2 0 2 6 6]
# (array([  1,   6,   7,  13,  18,  20,  23,  25,  37,  39,  41,  58,  62,
#          68,  74,  92,  97, 118, 119]),)

# %%
import numpy as np
from matplotlib import pyplot as plt


a = np.random.uniform(0, 2000, 100000)
plt.hist(a, bins = 50)
plt.show()

# %%
import numpy as np
s = input()
x = np.linspace(0, 1, 100)
y = eval(s)
print(y)
# Out:
#  2
# 2

# %%
i = np.random.uniform(a, b, 100)
n = len(i)

sum_list = []
for v in i:
    eval(function)
    np.append(sum_list)

arr = np.ndarray(sum_list)


integral = ((b - a)/n) * arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 i = np.random.uniform(a, b, 100)
#       2 n = len(i)
#       4 sum_list = []
#
# NameError: name 'b' is not defined

# %%
import numpy as np

seq = np.array([-100, -10, 0, 10, 100])
arr = np.asarray(seq)
a = np.where(seq <= 0, np.nan, arr)

np.log10(100)

# %%
while True:
   try:
      s = input("Please enter a number: ")
      x = float(s)
      break
   except ValueError:
      print("%s is not a valid number. Try again..."%s)

print("x=", x)
# Out:
# Please enter a number:  23
# x= 23.0
