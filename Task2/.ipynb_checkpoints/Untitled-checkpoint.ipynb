# %%
import math

# User can input their values for a, b and c.
a = float(input(f"Input your value for a:"))
b = float(input(f"Input your value for b:"))
c = float(input(f"Input your value for c:"))

# Using inputted values to calculate the discriminant
D = b**2 - 4 * a * c

print(f"The calculated value for the discriminant (D) is: {D}")

x_1 = (-b + D**0.5) / (2 * a)
x_2 = (-b - D**0.5) / (2 * a)

print(x_1)
print(x_2)

if D > 0:
    print(f"The calculated D was bigger then 0, which gives us the x values: x1 = {x_1} and x2 = {x_2}")
elif D == 0:
    print(f"The calculated D was equal to 0, which gives us one x value: x1 = {x_1}")
else:
    print(f"Your calculated D was smaller than 0, which gives no real solutions.")
# Out:
# Input your value for a: 4
# Input your value for b: 1
# Input your value for c: 8
# The calculated value for the discriminant (D) is: -127.0
# (-0.12499999999999992+1.4086784586980805j)
# (-0.12500000000000008-1.4086784586980805j)
# Your calculated D was smaller than 0, which gives no real solutions.
