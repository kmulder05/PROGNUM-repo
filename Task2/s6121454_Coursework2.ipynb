# %% [markdown]
# # Coursework Set Week 2

# %% [markdown]
# **Common remarks**:
#
# * Deadline: Sunday at 23:59h for the week of this task
# * <font color='red'>Keep all the information in this template unaltered!</font>
#
# **Please fill in the following fields:**
#
# * Name: Kevin Mulder
# * Username: kmulder
# * Student number: S6121454
# * Group (AS1, etc.): AS6
#
# -----

# %%
totalpoints = currentpoints = 0

# %% [markdown]
# ### Julian Date, a algorithm with some pitfalls (4 pt) <font color='red'><b>COURSEWORK</b></font>
#
# In the online article: [A one-line algorithm for Julian Date](http://adsabs.harvard.edu/full/1983IAPPP..13...16F)
# we find an old and very compact formula for programmable calculators to calculate a Julian Date given a day, month and year.
# A Julian Date is in fact a
# day number corresponding to the number of elapsed days since the beginning of a cycle of 7980 years.
# That makes it a useful tool to calculate how many days there are between two dates.
# The one-line algorithm is valid for the period that started in 1582 with the Gregorian calendar.
# The formula from the article is:
#
#
# ``JD = 367*Y -7*(Y+(M+9)/12)/4 - 3*((Y+(M-9)/7)/100 + 1)/4 + (275*M)/9 + D + 1721029-0.5``
#
# The article notes: **It is important to note that after all divisions in this expression only that portion of the
# quotient to the left of the decimal point is retained and that the quotient is not rounded off.**
#
# * Use your notebook to develop an implementation of this formula.
# * Then create a Python script called ``JD.py`` that asks a user to enter day, month and year. For this date, the script calculates the Julian Date (JD) and prints it. The day can be entered as a floating point number to allow for fractional days.
# * The article provides a test case: the Julian Date for January 4, 1700 is 2341975.5.
#   Use your code to get the correct result, and attach your screen shot in this notebook.&nbsp;
#
# Extend the program on the notebook, so that it can calculate the number of days between two dates in the Gregorian calendar. What is your age expressed in days?
#
# **Answers**:

# %% [markdown]
# ![Screenshot_20260217_140317.png](attachment:9e9cb84c-32ed-4ff9-b10b-80d2eb6fe0f0.png)

# %%
# The user can input the date of that day
D_c = float(input(f"Put current day: "))
M_c = float(input(f"Put current month: "))
Y_c = float(input(f"Put current year: "))

# The user can input their own birthday
D_b = float(input(f"Put day of birth: "))
M_b = float(input(f"Put month of birth: "))
Y_b = float(input(f"Put year of birth: "))

# Calculating both the Julian dates of the current day and the birthday
JD_1 = 367*Y_c -7*(Y_c+(M_c+9)//12)//4 - 3*((Y_c+(M_c-9)//7)//100 + 1)//4 + (275*M_c)//9 + D_c + 1721029-0.5  # Date of current day
JD_2 = 367*Y_b -7*(Y_b+(M_b+9)//12)//4 - 3*((Y_b+(M_b-9)//7)//100 + 1)//4 + (275*M_b)//9 + D_b + 1721029-0.5  # Date of birthday

# Calculating the difference to find the age in days
JD_b = JD_1 - JD_2 

print(f"Your age in days is: {JD_b}")
# Out:
# Put current day:  19
# Put current month:  2
# Put current year:  2026
# Put day of birth:  10
# Put month of birth:  7
# Put year of birth:  2005
# Your age in days is: 7529.0

# %%
# Leave unaltered
totalpoints += 4
currentpoints += 0.0

# %% [markdown]
# ###  Calculating the roots of a second degree polynomial (3 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Use your notebook to develop the necessary code and then which solves for the roots
# of $f(x)=ax^2+bx+c$ for values of ``a``, ``b`` and ``c`` entered by a user of your program.
# All the required information related to this question is included in the notebook about conditions.
#
# You have to remember that
#
# $$f(x)=ax^2+bx+c$$
#
# has two solutions:
#
# $$x_1=\frac{-b + \sqrt{b^2-4ac}}{2a} \quad\text{and}\quad x_2=\frac{-b - \sqrt{b^2-4ac}}{2a}$$
#
# only if:
#
# $$\begin{split}D= b^2-4ac>0\end{split}$$
#
# It has one solution if $D == 0$ and no solutions (at least no real solutions) if $D < 0$.
#
# * Use the ``if,elif,else`` construct to print either two solutions, one solution or an message that no solutions
#  could be found.
# * Use f-strings for your output if there are solutions.
# * Include your code with an input example and its output in your notebook.
# * Use your notebook code to create a script called ``abc.py``.
# * On Terminal, run your python script, screenshot the result, and attach the it here.
#
# **Answer**:

# %%
# User can input their values for a, b and c.
a = float(input(f"Input your value for a:"))
b = float(input(f"Input your value for b:"))
c = float(input(f"Input your value for c:"))

# Using inputted values to calculate the discriminant
D = b**2 - 4 * a * c

print(f"The calculated value for the discriminant (D) is: {D}")

x_1 = (-b + D**0.5) / (2 * a)
x_2 = (-b - D**0.5) / (2 * a)

# Gives the x values if there is one, otherwise it tells you that there are no real solutions
if D > 0:
    print(f"The calculated D is bigger then 0, which gives us the x values: x1 = {x_1} and x2 = {x_2}")
elif D == 0:
    print(f"The calculated D is equal to 0, which gives us one x value: x1 = {x_1}")
else:
    print(f"Your calculated D is smaller than 0, which gives no real solutions.")

# When using a = 2, b = 7 and c= 3, it tells you that the value for D is bigger than zero and that your x values are x1 = -0.5 and x2 = -3.0
# Out:
# Input your value for a: 4
# Input your value for b: 2
# Input your value for c: -9
# The calculated value for the discriminant (D) is: 148.0
# The calculated D is bigger then 0, which gives us the x values: x1 = 1.2706906325745548 and x2 = -1.7706906325745548

# %% [markdown]
# ![Screenshot_20260219_125726.png](attachment:ddfa6178-85a8-4dbd-a342-180145c83c6d.png)

# %%
# Leave unaltered
totalpoints += 3
currentpoints += 0.0

# %% [markdown]
# ### Uniqueness in lists using the `set` object (2 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Given two lists with a number of gamma ray bursts per night for two different periods
#
# ```python
#     night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
#     night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
# ```
#
# Use Python sequence type `set` to create a **list**:
#
# 1. with values that are both in `night1` and `night2`.
# 1. with values that are the difference between `night1` and `night2`.
# 1. with values that contains all items from both sets, duplicates are excluded.
# 1. after an update of `night1` by removing all its elements that are not available in `night2`.
#
# **Answers**:

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]

# Make a set version of both lists with set()
set_night1 = set(night1)
set_night2 = set(night2)

# Make a list of common values
common_v = set_night1 & set_night2
list_common_v = list(common_v)
print(f"A list of common values: {list_common_v}")

# Make a list of difference between both lists
diff = set_night1.difference(set_night2)
list_diff = list(diff)
print(f"A list of all different values between the sets night 1 and night 2: {list_diff}")

# Make a list with all items of both sets, no duplicates
set_all_values = set_night1.union(set_night2)
list_all_values = list(set_all_values)
print(f"A list of all values in night 1 and 2 without duplicates: {list_all_values}")

# Update the list of night 1 with only values that are in night2
update_night1 = set_night1^set_night2  # Find difference
new_set_night1 = set_night1.difference(update_night1)  # Removes all values that were not in night 2, from night 1
list_update_night1 = list(new_set_night1)
print(f"New list of night1 with only the values that are also in night2: {list_update_night1}")
# Out:
# A list of common values: [0, 1, 2, 3, 4]
# A list of all different values between the sets night 1 and night 2: [9, 5, 7]
# A list of all values in night 1 and 2 without duplicates: [0, 1, 2, 3, 4, 5, 7, 9]
# New list of night1 with only the values that are also in night2: [0, 1, 2, 3, 4]

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0.0

# %% [markdown]
# ### Change a value in a dictionary (2 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Given the Python dictionary:
#
# ```python
# planetsmass = { 'Mercury' : 0.33,
#                 'Venus'   : 4.87, 'Earth'   : 5.98,
#                 'Mars'    : 0.65, 'Jupiter' : 1900,
#                 'Saturn'  :  570, 'Uranus'  :  87,
#                 'Neptune' :  100, 'Pluto'   :  0.7 }
# ```
#
# 1. Extract from this dictionary a Python **list** with only the names of the objects.
# 1. Print the mass of Venus in Earth masses.
# 1. Remove Pluto from your dictionary.
# 1. Add Planet Nine with mass 29.3 to the dictionary.
# 1. Print the modified dictionary.
#
#
# **Answer**:

# %%
planetsmass = { 'Mercury' : 0.33,
                'Venus'   : 4.87, 'Earth'   : 5.98,
                'Mars'    : 0.65, 'Jupiter' : 1900,
                'Saturn'  :  570, 'Uranus'  :  87,
                'Neptune' :  100, 'Pluto'   :  0.7 }

# Prints a list of the names in the planetsmass dictionary
names_list = planetsmass.keys()
print(names_list)
print()

# Printing mass of Venus in earth masses
mass_venus = planetsmass['Venus']
mass_earth = planetsmass['Earth']
m_venus_in_earth = mass_venus / mass_earth
print(f"The mass of venus in earth masses is: {m_venus_in_earth}")

# Removing Pluto from the dictionary
planetsmass.pop('Pluto')
print(f"Removing Pluto gives us: {planetsmass}")

# Adding planet nine with a given value and also printing the new list without Pluto
planetsmass['Planet Nine'] = 29.3
print(f"Adding planet nine gives us: {planetsmass}")
# Out:
# dict_keys(['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune', 'Pluto'])
#
# The mass of venus in earth masses is: 0.81438127090301
# Removing Pluto gives us: {'Mercury': 0.33, 'Venus': 4.87, 'Earth': 5.98, 'Mars': 0.65, 'Jupiter': 1900, 'Saturn': 570, 'Uranus': 87, 'Neptune': 100}
# Adding planet nine gives us: {'Mercury': 0.33, 'Venus': 4.87, 'Earth': 5.98, 'Mars': 0.65, 'Jupiter': 1900, 'Saturn': 570, 'Uranus': 87, 'Neptune': 100, 'Planet Nine': 29.3}

# %% [markdown]
# # Leave unaltered
# totalpoints += 2
# currentpoints += 0.0

# %% [markdown]
# ### Apply NumPy functions to data (2pt) <font color='red'><b>COURSEWORK</b></font>
#
# * Create a NumPy array `x` with 100 angles in degrees between 0 and 360 degrees using ``np.linspace()``
# * Calculate the ``np.sinc(x)`` values of ``x``, with ``x`` in radians. The definition of the sinc function is:
#
#   $$\mathrm{sinc}(x) = \frac{\sin(\pi x)}{\pi x}$$
#
# * Print the first 10 values of the result.
#
# **Answer**

# %%
import numpy as np

x = np.linspace(0, 360, 100)
a = np.sinc(np.radians(x))
print(f"First ten resulting values: {a[0:10:1]}")
# Out:
# First ten resulting values: [1.         0.99338737 0.97370676 0.94142562 0.89730831 0.84239452
#  0.77797001 0.70553048 0.62673987 0.5433841 ]

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0.0

# %% [markdown]
# ## Finishing up
#
# **Please read the section about your report in the task documentation very carefully before submitting it to BrightSpace.**
#
# ------------

# %% [markdown]
# ## T.A. Grading

# %%
# Leave unaltered
taskgrade = round(10*currentpoints/totalpoints, 1) if totalpoints != 0 else 0
print(f"Total number of points: {totalpoints}. Student score: {currentpoints}.  Task Grade = {taskgrade}")
# Out:
# Total number of points: 11. Student score: 0.0.  Task Grade = 0.0
