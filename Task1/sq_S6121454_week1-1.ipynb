# %% [markdown]
# Answers for week 1
#
# * Name: Kevin Mulder
# * Username: kmulder
# * Student s-number: S6121454
# * Group: AS6

# %%
x = 22/7

# %% [markdown]
# $$ y=\frac{sin(x)}{x} $$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %%
# 1.5

from scipy.constants import G

m_moon= 7.342 * 10**22
m_earth = 5.9722 * 10**24
r = 385000.6 *10**3
F = G*((m_earth)*(m_moon))/r**2

print(F)
# Out:
# 1.974384051807571e+20

# %% [markdown]
# # 1.10
#
# ![Schermafbeelding 2026-02-12 124511.png](attachment:3cd3dc29-f26b-4633-8e5b-5323fe90f8f9.png)

# %% [markdown]
# # 1.11
#
# ![Screenshot_20260212_125047.png](attachment:27347014-0309-4b78-bb7a-fe8ceef560af.png)

# %% [markdown]
# # 1.12
#
# ![Screenshot_20260212_125338.png](attachment:d3d159e4-4bfe-400a-887e-2c71ee8f1e9c.png)

# %% [markdown]
# # 1.15

# %% [markdown]
# 1) It will give you the absolute to the path the directory Downloads
# 2) ' . ' in this case refers to the directory Downloads.
# -  ' .. ' in this case refers to the home directory, which is one step up.

# %% [markdown]
# # 1.16 (still check)
#
# 1) cd ~/Desktop
