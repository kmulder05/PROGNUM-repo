# %% [markdown]
# ![M101_5-9-22WM-WEB.webp](attachment:7891b47a-315a-436e-9d7e-c554bb0a249b.webp)

# %% [markdown]
# 1. It says /bin/bash
# 2. It makes a list of all my folders and documents in the directory I am in.
# 3. It makes the list better visible.
# 4.
