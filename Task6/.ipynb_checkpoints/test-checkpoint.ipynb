# %%
import numpy as np

class Fibonacci:
    """Class for calculating Fibonacci sequence"""
    def __init__(self, N, M):
        self.N = N
        self.M = M
    def fib_sequence(self):
        fibo = [0, 1]
        for i in range(1000):
            fibo.append(fibo[-1] + fibo[-2])
        return f"The {self.N}th term in the sequence is: {fibo[self.N]}"
    def lesser(self):
        fibo = [0, 1]
        while fibo[-1] < self.N:
            if fibo[-1] % self.M == 0:
                result.append(fibo[-1])
                fib.append(fibo[-1] + fibo[-2])
        if self.N > 0 and 0 % self.M == 0:
            result.insert(0, 0)
        return result
            
        
fib = Fibonacci(100, 7)
fib.fib_sequence()
fib.lesser()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 26
#      24 fib = Fibonacci(100, 7)
#      25 fib.fib_sequence()
# ---> 26 fib.lesser()
#
# Cell In[1], line 15, in Fibonacci.lesser(self)
#      13 def lesser(self):
#      14     fibo = [0, 1]
# ---> 15     while fibo[-1] < self.N:
#      16         if fibo[-1] % self.M == 0:
#      17             result.append(fibo[-1])
#
# KeyboardInterrupt:

# %%
from pathlib import Path
import os
from astropy.io import fits

home = Path.home()
datapath = Path("PROGNUM-repo/Task6/20210422_Li_.00000066.FIT")
path = home / datapath

hdulist = fits.open(path)
hdulist.info()
image_data = hdulist[0].data
if 'int' in str(image_data.dtype):
    image_data = image_data.astype('float')
print("\n ===> Number type:", image_data.dtype)
# Out:
# Filename: /Users/users/kmulder/PROGNUM-repo/Task6/20210422_Li_.00000066.FIT
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      44   (3072, 2048)   int16 (rescales to uint16)
#
#  ===> Number type: float64
